# %% [markdown]
# <a href="https://colab.research.google.com/github/prdurgam-edu/DataScience_CourseWork/blob/main/AurelienGeron_03_TrainingModels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import datasets
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Data

# %%
X = 2*np.random.rand(100,1)
y= 4+ 3*X + np.random.randn(100,1)

# %%
plt.plot(X,y,"b.")
plt.grid()
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x_b = np.c_[np.ones((100,1)),X]

# %%
theta_best = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)

# %%
theta_best
# Out:
# array([[4.1446569 ],
#        [2.86801704]])

# %%
plt.plot(X,x_b.dot(theta_best),"r--")
plt.plot(X,y,"b.")
plt.plot()
plt.grid()

# %%
lin_reg=LinearRegression()
lin_reg.fit(X,y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([4.1446569]), array([[2.86801704]]))

# %%
m=100
X=6*np.random.rand(m,1)-3
y=0.5*X**2+ X+2 + np.random.randn(m,1)

# %%
poly_features= PolynomialFeatures(degree=2,include_bias=False)
X_poly =  poly_features.fit_transform(X)
print(X[0], X_poly[0])
# Out:
# [-1.22504753] [-1.22504753  1.50074146]

# %%
lin_reg= LinearRegression()
lin_reg.fit(X_poly, y)
lin_reg.intercept_ , lin_reg.coef_
# Out:
# (array([1.90768168]), array([[1.0744259 , 0.53809029]]))

# %%
y_pred= lin_reg.intercept_+ X_poly.dot(lin_reg.coef_.T)

# %%
plt.plot(X,y_pred,"r.")
plt.plot(X,y,"b.")
plt.plot()
plt.grid()

# %%
iris=datasets.load_iris()
list(iris.keys())
# Out:
# ['data',
#  'target',
#  'frame',
#  'target_names',
#  'DESCR',
#  'feature_names',
#  'filename',
#  'data_module']

# %%
X=iris['data'][:,3:]
y=(iris['target']==2).astype(int)

# %%
log_reg = LogisticRegression()
log_reg.fit(X,y)
# Out:
# LogisticRegression()

# %%
x_new = np.linspace(0,3,1000).reshape(-1,1)
y_proba = log_reg.predict_proba(x_new)

plt.plot(x_new, y_proba[:,:1], 'g--', label='Iris Virginica')
plt.plot(x_new, y_proba[:,1:], 'r--', label='Not Iris Virginica')
plt.xlabel("width")
plt.ylabel("proba")
plt.legend()
plt.grid()
